# %% [markdown]
# <a href="https://colab.research.google.com/github/TharunRaja-1106/Python_Exercises/blob/main/Extra_Assignment_Level_3_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
value = int(input("value: "))
if value == 10:
    print("Correct")
else:
    print("Incorrect")
# Out:
# value: 10
# Correct

# %%
password = input("Enter the password: ")
if password == "HOPE@123":
    print("Your password is correct")
else:
    print("Your password is incorrect")
# Out:
# Enter the password: HOPE
# Your password is incorrect

# %%
age=int(input("Enter your age:"))
if age<18:
    print("Children")
elif age<35:
    print("Adult")
elif age<59:
    print("Citizen")
else:
    print("Senior Citizen")
# Out:
# Enter your age:19
# Adult

# %%
num = int(input("Enter any number:"))
if num >= 0:
    print("No is positive")
else:
    print("No is negative")
# Out:
# Enter any number:-1
# No is negative

# %%
num = int(input("Enter a number to check:"))
if num % 5 == 0:
    print("No is divisible by 5")
else:
    print("No is not divisible by 5")
# Out:
# Enter a number to check:45
# No is divisible by 5
